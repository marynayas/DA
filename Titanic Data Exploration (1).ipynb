# %% [markdown]
# ## Titanic Data Exploration ##
#
# ***
#
# Over the past several weeks, you've learned the code about how to explore and manipulate a dataset. Now it's time to practice what you've learned on a real-world dataset.
#
# ***
#
# ### Titanic Dataset
#
# The titanic dataset holds information about the passengers on the titanic. This includes passenger name, characteristics, and if they survived the accident. The dataset has the following columns:
#
#     * pclass = passenger class; 1 = first class, 2 = second class, 3 = third class
#     * survived = passenger survival; 1 = survived, 0 = did not survive
#     * name = passenger name
#     * sex = sex of passenger
#     * age = age of passenger
#     * sibsp = # of siblings / spouses aboard the Titanic
#     * parch = # of parents / children aboard the Titanic
#     * ticket = ticket number
#     * fare = fare paid by passenger
#     * cabin = passenger cabin
#     * embarked = port of embarkation; C = Cherbourg, Q = Queenstown, S = Southampton
#     * boat = lifeboat assignment
#     * body = recovered body number
#     * home dest = anticipated home destination
#
# If you need some additional motivation before starting, please visit: https://www.youtube.com/watch?v=3gK_2XdjOdY
#
# ### How to work through the dataset:
#
# Follow the prompts below to explore, manipulate, and visualize aspects of the dataset. Working with data takes time, so take your time as you start with a messy dataset and turn it into something that shows meaningful visualizations.
#
# ***

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Import Libraries and Dataset
#
# * Review the entire notebook to determine what you will be expected to do - then, import the necessary libraries
# * Import the titanic.xlsx dataset

# %%
titanic = pd.read_excel("titanic.xlsx")
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
titanic.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %% [markdown]
# ### Determine the Characteristics of the Dataset
#
#    * How many columns are in this dataset?
#    * How many rows are in this dataset?
#    * What types of data are in each column? Does this make sense with that you know about that column?
#    * Which variables are numeric? Which variables are categorical? What other variables are left outside of these two groups?
#    * Which variable could be considered a 'dependent' variable?

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic.shape #1309 rows, 14 columns
# Out:
# (1309, 14)

# %% [markdown]
# How many columns are in this dataset?
# #### 14 columns
#
# How many rows are in this dataset?
# #### 1309 rows
#
# What types of data are in each column?
# #### data types: float64(3), int64(4), object(7)
#
# Does this make sense with that you know about that column?
#
# #### It makes sense because I can manipulate with data in the certain way
#
# Which variables are numeric?
# #### age, sibsp =  of siblings / spouses aboard the Titanic; parch =  of parents / children aboard the Titanic; ticket = ticket number; fare =fare paid by passenger; boat = lifeboat assignment; body = recovered body number
#
# Which variables are categorical?
# #### name, sex, embarked = port of embarkation, home dest, survived
#
# What other variables are left outside of these two groups?
# #### cabin
#
# Which variable could be considered a 'dependent' variable?
# #### "Survived" variables could be considered a "dependent" variable because surviving of a persn depends from an age, sex, and wellness: passenger class, lifeboat assignment.

# %% [markdown]
# ### Identify the Missing Data in the Dataset
#
#    * Is there any missing data?
#    * Which columns have any missing data?
#    * Which column has the most missing information? Which column has the least?

# %%
## Columns have any missing data: pcclass, survived, name, sex, sibsp, 
Which column has the most missing information? Which column has the least?
# Out:
# Object `least` not found.

# %%
titanic.isnull().sum()
# Out:
# pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
titanic.loc[titanic.isnull().any(axis = 1)]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.0000      0      0   24160  211.3375       B5        S    2
# 1       male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...      ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.5000      1      0    2665   14.4542      NaN        C  NaN
# 1305  female      NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.5000      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.0000      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.0000      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]

# %% [markdown]
# ### Handling the Missing Data in the Dataset
#
#    * Remove the columns with excessive missing data (any column missing greater than 500 rows)
#    * When there is very little missing data, we can make replacements. Replace the missing data for the "embarked" column with the most common embarkation point.
#    * Replace the missing data in "fare" with the average fare of the entire sample.
#    * Remove the rows in the dataset that has missing "age" data.
#    * Recheck is there is any data missing in the dataset.

# %%
#Remove the columns with excessive missing data (any column missing greater than 500 rows)
titanic_copy = titanic.copy()
print(titanic_copy.shape)
# Out:
# (1309, 14)

# %%
titanic_copy.drop(columns=["cabin", "boat", "body", "home.dest"], inplace = True)
titanic_copy.shape
# Out:
# (1309, 10)

# %%
#When there is very little missing data, we can make replacements. 
#Replace the missing data for the "embarked" column with the most common embarkation point.

##S - the most common embarkation point = 914
titanic_copy["embarked"].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
titanic_copy["embarked"].value_counts("NaN")
# Out:
# S    0.699311
# C    0.206580
# Q    0.094109
# Name: embarked, dtype: float64

# %%
#When there is very little missing data, we can make replacements. 
#Replace the missing data for the "embarked" column with the most common embarkation point.

titanic_copy['embarked'].replace("NaN", "S", inplace=True)

titanic_copy.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare embarked
# 0  29.0000      0      0   24160  211.3375        S
# 1   0.9167      1      2  113781  151.5500        S
# 2   2.0000      1      2  113781  151.5500        S
# 3  30.0000      1      2  113781  151.5500        S
# 4  25.0000      1      2  113781  151.5500        S

# %%
titanic_copy["embarked"].value_counts()
# Out:
# S    914
# C    270
# Q    123
# Name: embarked, dtype: int64

# %%
titanic_copy.isnull().sum()
# Out:
# pclass        0
# survived      0
# name          0
# sex           0
# age         263
# sibsp         0
# parch         0
# ticket        0
# fare          1
# embarked      2
# dtype: int64

# %%
titanic_copy['embarked'].fillna("S", inplace=True)
titanic_copy.isnull().sum()
# Out:
# pclass        0
# survived      0
# name          0
# sex           0
# age         263
# sibsp         0
# parch         0
# ticket        0
# fare          1
# embarked      0
# dtype: int64

# %%
#Replace the missing data in "fare" with the average fare of the entire sample.

x = titanic_copy['fare'].mean()
x
# Out:
# 33.29547928134572

# %%
titanic_copy['fare'].replace("NaN", "x", inplace=True)

titanic_copy.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare embarked
# 0  29.0000      0      0   24160  211.3375        S
# 1   0.9167      1      2  113781  151.5500        S
# 2   2.0000      1      2  113781  151.5500        S
# 3  30.0000      1      2  113781  151.5500        S
# 4  25.0000      1      2  113781  151.5500        S

# %%
#Remove the rows in the dataset that has missing "age" data.
titanic_copy.dropna(subset=["age"], inplace = True)

# %%
#Recheck is there is any data missing in the dataset.
titanic_copy.isnull().sum()
# Out:
# pclass      0
# survived    0
# name        0
# sex         0
# age         0
# sibsp       0
# parch       0
# ticket      0
# fare        1
# embarked    0
# dtype: int64

# %% [markdown]
# ### Creating Columns and Replacing Labels
#
#    * Create descriptive labels for the categorical columns: pclass, survived, and embarked. Instead of the coding that shows in the dataset, create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)
#    * Create a new column called "Titanic Passenger" and make all values 1
#    * Create a new column called "Family Size" - this column should equal the total number of family members each passenger was traveling with.
#    * Create a column called "Travel Alone" - this column should be 1 if the passenger was traveling alone, and 0 if the passenger was traveling with family.
#    * Create a column called "Has Caregiver" - this column should have a value of 1 if a passenger is less than 13-years old AND the passenger is traveling with at least one family member, otherwise the value should be 0.
#    * Create a column called "Crew" - this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.
#    * Create a column called "Age Group" to group passengers by their age (create five categories: infant, child, teen, adult, senior). You can use bins to complete this (or any other method you like). You define the cutoff points for each group you create.
#
# After create new columns, replace the basic coding "0/1" with meaningful labels.

# %%
#Create descriptive labels for the categorical columns: pclass, survived, and embarked. Instead of the coding that shows in the dataset, create labels to describe what each category represents (i.e. in the embarked column S = Southhampton)

titanic_copy["pclass"].replace([1, 2, 3], ["1st Class", "2nd Class", "3rd Class"], inplace = True)

###

titanic_copy["survived"].replace([0, 1], ["Died", "Survived"], inplace = True)

###

titanic_copy["embarked"].replace(["C", "Q", "S"], ["Cherbourg", "Queenstown", "Southampton"], inplace = True)

####

titanic_copy.head()
# Out:
#       pclass  survived                                             name  \
# 0  1st Class  Survived                    Allen, Miss. Elisabeth Walton
# 1  1st Class  Survived                   Allison, Master. Hudson Trevor
# 2  1st Class      Died                     Allison, Miss. Helen Loraine
# 3  1st Class      Died             Allison, Mr. Hudson Joshua Creighton
# 4  1st Class      Died  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare     embarked
# 0  female  29.0000      0      0   24160  211.3375  Southampton
# 1    male   0.9167      1      2  113781  151.5500  Southampton
# 2  female   2.0000      1      2  113781  151.5500  Southampton
# 3    male  30.0000      1      2  113781  151.5500  Southampton
# 4  female  25.0000      1      2  113781  151.5500  Southampton

# %%
#Create a new column called "Titanic Passenger" and make all values 1

titanic_copy["Titanic Passenger"] = 1
titanic_copy.head()
# Out:
#       pclass  survived                                             name  \
# 0  1st Class  Survived                    Allen, Miss. Elisabeth Walton
# 1  1st Class  Survived                   Allison, Master. Hudson Trevor
# 2  1st Class      Died                     Allison, Miss. Helen Loraine
# 3  1st Class      Died             Allison, Mr. Hudson Joshua Creighton
# 4  1st Class      Died  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare     embarked  \
# 0  female  29.0000      0      0   24160  211.3375  Southampton
# 1    male   0.9167      1      2  113781  151.5500  Southampton
# 2  female   2.0000      1      2  113781  151.5500  Southampton
# 3    male  30.0000      1      2  113781  151.5500  Southampton
# 4  female  25.0000      1      2  113781  151.5500  Southampton
#
#    Titanic Passenger
# 0                  1
# 1                  1
# 2                  1
# 3                  1
# 4                  1

# %%
#Create a new column called "Family Size" - this column should equal the total number of family members each passenger was traveling with.
titanic_copy["Family Size"] = titanic_copy["sibsp"] + titanic_copy["parch"]
titanic_copy.head()
# Out:
#       pclass  survived                                             name  \
# 0  1st Class  Survived                    Allen, Miss. Elisabeth Walton
# 1  1st Class  Survived                   Allison, Master. Hudson Trevor
# 2  1st Class      Died                     Allison, Miss. Helen Loraine
# 3  1st Class      Died             Allison, Mr. Hudson Joshua Creighton
# 4  1st Class      Died  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare     embarked  \
# 0  female  29.0000      0      0   24160  211.3375  Southampton
# 1    male   0.9167      1      2  113781  151.5500  Southampton
# 2  female   2.0000      1      2  113781  151.5500  Southampton
# 3    male  30.0000      1      2  113781  151.5500  Southampton
# 4  female  25.0000      1      2  113781  151.5500  Southampton
#
#    Titanic Passenger  Family Size
# 0                  1            0
# 1                  1            3
# 2                  1            3
# 3                  1            3
# 4                  1            3

# %%
#Create a column called "Travel Alone" - this column should be 1 if the passenger was traveling alone, and 0 if the passenger was traveling with family.

titanic_copy["Travel Alone"] = np.where(titanic_copy["Family Size"] == 0, "Alone", "With Family")
titanic_copy["Travel Alone"].replace(["Alone", "With Family"], [1,0], inplace=True)
titanic_copy.head()
# Out:
#       pclass  survived                                             name  \
# 0  1st Class  Survived                    Allen, Miss. Elisabeth Walton
# 1  1st Class  Survived                   Allison, Master. Hudson Trevor
# 2  1st Class      Died                     Allison, Miss. Helen Loraine
# 3  1st Class      Died             Allison, Mr. Hudson Joshua Creighton
# 4  1st Class      Died  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare     embarked  \
# 0  female  29.0000      0      0   24160  211.3375  Southampton
# 1    male   0.9167      1      2  113781  151.5500  Southampton
# 2  female   2.0000      1      2  113781  151.5500  Southampton
# 3    male  30.0000      1      2  113781  151.5500  Southampton
# 4  female  25.0000      1      2  113781  151.5500  Southampton
#
#    Titanic Passenger  Family Size  Travel Alone
# 0                  1            0             1
# 1                  1            3             0
# 2                  1            3             0
# 3                  1            3             0
# 4                  1            3             0

# %%
#Create a column called "Has Caregiver" - 
#this column should have a value of 1 if a passenger is less than 13-years old 
#AND the passenger is traveling with at least one family member, 
#otherwise the value should be 0.
titanic_copy["Has Caregiver"] = np.where((titanic_copy["Family Size"] > 0) & (titanic_copy["age"] < 13), "Has Caregiver", "No Caregiver")

# %%
#Create a column called "Crew" - this column should be 1 if the passenger paid 0 dollars for their ticket, and 0 otherwise.
titanic_copy["Crew"] = np.where((titanic_copy["fare"] == 0), "Crew", "Passenger")
titanic_copy.head()
# Out:
#       pclass  survived                                             name  \
# 0  1st Class  Survived                    Allen, Miss. Elisabeth Walton
# 1  1st Class  Survived                   Allison, Master. Hudson Trevor
# 2  1st Class      Died                     Allison, Miss. Helen Loraine
# 3  1st Class      Died             Allison, Mr. Hudson Joshua Creighton
# 4  1st Class      Died  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare     embarked  \
# 0  female  29.0000      0      0   24160  211.3375  Southampton
# 1    male   0.9167      1      2  113781  151.5500  Southampton
# 2  female   2.0000      1      2  113781  151.5500  Southampton
# 3    male  30.0000      1      2  113781  151.5500  Southampton
# 4  female  25.0000      1      2  113781  151.5500  Southampton
#
#    Titanic Passenger  Family Size  Travel Alone  Has Caregiver       Crew
# 0                  1            0             1   No Caregiver  Passenger
# 1                  1            3             0  Has Caregiver  Passenger
# 2                  1            3             0  Has Caregiver  Passenger
# 3                  1            3             0   No Caregiver  Passenger
# 4                  1            3             0   No Caregiver  Passenger

# %% [markdown]
# Create a column called "Age Group" to group passengers by their age (create five categories: infant, child, teen, adult, senior).
# You can use bins to complete this (or any other method you like).
# You define the cutoff points for each group you create.

# %%
bins = [0, 2, 13, 18, 65, 120]
bin_names = ["Infant", "Child", "Teen", "Adult", "Senior"]

titanic_copy["Age Group"] =  pd.cut(titanic_copy["age"], bins, labels=bin_names)
titanic_copy.head()
# Out:
#       pclass  survived                                             name  \
# 0  1st Class  Survived                    Allen, Miss. Elisabeth Walton
# 1  1st Class  Survived                   Allison, Master. Hudson Trevor
# 2  1st Class      Died                     Allison, Miss. Helen Loraine
# 3  1st Class      Died             Allison, Mr. Hudson Joshua Creighton
# 4  1st Class      Died  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare     embarked  \
# 0  female  29.0000      0      0   24160  211.3375  Southampton
# 1    male   0.9167      1      2  113781  151.5500  Southampton
# 2  female   2.0000      1      2  113781  151.5500  Southampton
# 3    male  30.0000      1      2  113781  151.5500  Southampton
# 4  female  25.0000      1      2  113781  151.5500  Southampton
#
#    Titanic Passenger  Family Size  Travel Alone  Has Caregiver       Crew  \
# 0                  1            0             1   No Caregiver  Passenger
# 1                  1            3             0  Has Caregiver  Passenger
# 2                  1            3             0  Has Caregiver  Passenger
# 3                  1            3             0   No Caregiver  Passenger
# 4                  1            3             0   No Caregiver  Passenger
#
#   Age Group
# 0     Adult
# 1    Infant
# 2    Infant
# 3     Adult
# 4     Adult

# %% [markdown]
# ### Determine Frequencies of Groups
#
# * How many passengers fall into each category? Determine how many passengers fall into each group for <b>each</b> categorical vairable (including the ones you just created).

# %%
#categorical vairables: pclass, survived, name, sex, embarked, Has Caregiver, Crew, Age Group
##pclass

titanic_copy[['pclass']].value_counts()
# Out:
# pclass
# 3rd Class    501
# 1st Class    284
# 2nd Class    261
# dtype: int64

# %%
#survived
titanic_copy[['survived']].value_counts()
# Out:
# survived
# Died        619
# Survived    427
# dtype: int64

# %%
#name
titanic_copy[['name']].value_counts()
# Out:
# name
# Connolly, Miss. Kate                                  2
# Kelly, Mr. James                                      2
# Abbing, Mr. Anthony                                   1
# Nasser, Mrs. Nicholas (Adele Achem)                   1
# Nesson, Mr. Israel                                    1
#                                                      ..
# Farrell, Mr. James                                    1
# Faunthorpe, Mr. Harry                                 1
# Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkinson)    1
# Fillbrook, Mr. Joseph Charles                         1
# van Billiard, Mr. Austin Blyler                       1
# Length: 1044, dtype: int64

# %%
#sex 
titanic_copy[['sex']].value_counts()
# Out:
# sex
# male      658
# female    388
# dtype: int64

# %%
#embarked
titanic_copy[['embarked']].value_counts()
# Out:
# embarked
# Southampton    784
# Cherbourg      212
# Queenstown      50
# dtype: int64

# %%
#Has Caregiver 
titanic_copy[['Has Caregiver']].value_counts()
# Out:
# Has Caregiver
# No Caregiver     955
# Has Caregiver     91
# dtype: int64

# %%
#Crew
titanic_copy[['Crew']].value_counts()
# Out:
# Crew
# Passenger    1038
# Crew            8
# dtype: int64

# %%
# Age Group
titanic_copy[['Age Group']].value_counts()
# Out:
# Age Group
# Adult        843
# Teen          94
# Child         65
# Infant        34
# Senior        10
# dtype: int64

# %% [markdown]
# ### Determine the Distribution of Numeric Data
#
# * What are the summary statistics for <b>each</b> numeric variable in the dataset? Summary statistics include:
#     * Mean
#     * Median
#     * Mode
#     * Standard Deviation
#     * Range

# %%
titanic_copy.describe()
# Out:
#                age        sibsp       parch         fare  Titanic Passenger  \
# count  1046.000000  1046.000000  1046.00000  1045.000000             1046.0
# mean     29.881135     0.502868     0.42065    36.686080                1.0
# std      14.413500     0.912167     0.83975    55.732533                0.0
# min       0.166700     0.000000     0.00000     0.000000                1.0
# 25%      21.000000     0.000000     0.00000     8.050000                1.0
# 50%      28.000000     0.000000     0.00000    15.750000                1.0
# 75%      39.000000     1.000000     1.00000    35.500000                1.0
# max      80.000000     8.000000     6.00000   512.329200                1.0
#
#        Family Size  Travel Alone
# count  1046.000000   1046.000000
# mean      0.923518      0.564054
# std       1.452891      0.496117
# min       0.000000      0.000000
# 25%       0.000000      0.000000
# 50%       0.000000      1.000000
# 75%       1.000000      1.000000
# max      10.000000      1.000000

# %%
titanic_copy.mode()
# Out:
#       pclass survived                  name   sex   age  sibsp  parch  \
# 0  3rd Class     Died  Connolly, Miss. Kate  male  24.0    0.0    0.0
# 1        NaN      NaN      Kelly, Mr. James   NaN   NaN    NaN    NaN
#
#     ticket  fare     embarked  Titanic Passenger  Family Size  Travel Alone  \
# 0  CA 2144  13.0  Southampton                1.0          0.0           1.0
# 1      NaN   NaN          NaN                NaN          NaN           NaN
#
#   Has Caregiver       Crew Age Group
# 0  No Caregiver  Passenger     Adult
# 1           NaN        NaN       NaN

# %%
#numeric variables: age sibsp parch fare Family Size
##age

range_age = titanic_copy['age'].max() - titanic_copy['age'].min()
print("Range age: ", range_age)

mode_age = titanic_copy['age'].mode()
print("Mode age: ", mode_age)

median_age = titanic_copy['age'].median()
print("Median age: ", median_age)
# Out:
# Range age:  79.8333
# Mode age:  0    24.0
# Name: age, dtype: float64
# Median age:  28.0

# %%
#sibsp

range_sibsp = titanic_copy['sibsp'].max() - titanic_copy['sibsp'].min()
print("Range sibsp: ", range_sibsp)

mode_sibsp = titanic_copy['sibsp'].mode()
print("Mode sibsp: ", mode_sibsp)

median_sibsp = titanic_copy['sibsp'].median()
print("Median sibsp: ", median_sibsp)
# Out:
# Range sibsp:  8
# Mode sibsp:  0    0
# Name: sibsp, dtype: int64
# Median sibsp:  0.0

# %%
#parch

range_parch = titanic_copy['parch'].max() - titanic_copy['parch'].min()
print("Range parch: ", range_parch)

mode_parch = titanic_copy['parch'].mode()
print("Mode parch: ", mode_parch)

median_parch = titanic_copy['parch'].median()
print("Median parch: ", median_parch)
# Out:
# Range parch:  6
# Mode parch:  0    0
# Name: parch, dtype: int64
# Median parch:  0.0

# %%
#fare

range_fare = titanic_copy['fare'].max() - titanic_copy['fare'].min()
print("Range fare: ", range_fare)

mode_fare = titanic_copy['fare'].mode()
print("Mode fare: ", mode_fare)

median_fare = titanic_copy['fare'].median()
print("Median fare: ", median_fare)
# Out:
# Range fare:  512.3292
# Mode fare:  0    13.0
# Name: fare, dtype: float64
# Median fare:  15.75

# %%
#Family Size

range_FamilySize = titanic_copy['Family Size'].max() - titanic_copy['Family Size'].min()
print("Family Size: ", range_FamilySize)

mode_FamilySize = titanic_copy['Family Size'].mode()
print("Mode Family Size: ", mode_FamilySize)

median_FamilySize = titanic_copy['Family Size'].median()
print("Median Family Size: ", median_FamilySize)
# Out:
# Family Size:  10
# Mode Family Size:  0    0
# Name: Family Size, dtype: int64
# Median Family Size:  0.0

# %% [markdown]
# ### Relationships between Variables
#
# * Determine the relationship between each variable and the variable "survived". This is our primary variable of interest -- did this passenger survive the accident? Did the characteristics of the passenger have any relationship with their survival?
#     * <b>pclass</b>: how many survivors are in each passenger class? does a pattern emerge? which class has the most survivors? which has the least?
#     * <b>sex</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>age</b>: how does the average age of the passenger differ based on survival group?
#     * <b>age group</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>family size</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>travel alone</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>crew</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>has caregiver</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#     * <b>fare</b>: how does the average fare the passenger paid differ based on survival group?
#     * <b>embarked</b>: how many survivors are in each variable group? does a pattern emerge? which group has the most survivors? which has the least?
#
# Based on what you learn working through this section, make (2) statements about what characteristics of passenger most influenced their survival.

# %%
pd.crosstab(titanic_copy["pclass"], titanic_copy["survived"], margins = True)
# Out:
# survived   Died  Survived   All
# pclass
# 1st Class   103       181   284
# 2nd Class   146       115   261
# 3rd Class   370       131   501
# All         619       427  1046

# %%
#sex
pd.crosstab(titanic_copy['sex'], titanic_copy['survived'], margins=True)
# Out:
# survived  Died  Survived   All
# sex
# female      96       292   388
# male       523       135   658
# All        619       427  1046

# %%
#age

pd.crosstab(titanic_copy['age'], titanic_copy['survived'], margins=True)
# Out:
# survived  Died  Survived   All
# age
# 0.1667       0         1     1
# 0.3333       1         0     1
# 0.4167       0         1     1
# 0.6667       0         1     1
# 0.75         1         2     3
# ...        ...       ...   ...
# 71.0         2         0     2
# 74.0         1         0     1
# 76.0         0         1     1
# 80.0         0         1     1
# All        619       427  1046
#
# [99 rows x 3 columns]

# %%
#age group

pd.crosstab(titanic_copy['Age Group'], titanic_copy['survived'], margins=True)
# Out:
# survived   Died  Survived   All
# Age Group
# Infant       13        21    34
# Child        29        36    65
# Teen         56        38    94
# Adult       513       330   843
# Senior        8         2    10
# All         619       427  1046

# %%
#family size

pd.crosstab(titanic_copy["Family Size"], titanic_copy['survived'], margins=True)
# Out:
# survived     Died  Survived   All
# Family Size
# 0             402       188   590
# 1              93       113   206
# 2              63        81   144
# 3               9        30    39
# 4              11         6    17
# 5              20         5    25
# 6              12         4    16
# 7               8         0     8
# 10              1         0     1
# All           619       427  1046

# %%
#travel alone

pd.crosstab(titanic_copy['Travel Alone'], titanic_copy["survived"], margins=True)
# Out:
# survived      Died  Survived   All
# Travel Alone
# 0              217       239   456
# 1              402       188   590
# All            619       427  1046

# %%
#crew

pd.crosstab(titanic_copy["Crew"], titanic_copy['survived'], margins=True)
# Out:
# survived   Died  Survived   All
# Crew
# Crew          6         2     8
# Passenger   613       425  1038
# All         619       427  1046

# %%
#has caregiver
pd.crosstab(titanic_copy["Has Caregiver"], titanic_copy['survived'], margins=True)
# Out:
# survived       Died  Survived   All
# Has Caregiver
# Has Caregiver    39        52    91
# No Caregiver    580       375   955
# All             619       427  1046

# %%
#fare

pd.crosstab(titanic_copy["fare"], titanic_copy['survived'], margins=True)
# Out:
# survived  Died  Survived   All
# fare
# 0.0          6         2     8
# 3.1708       0         1     1
# 4.0125       1         0     1
# 5.0          1         0     1
# 6.2375       1         0     1
# ...        ...       ...   ...
# 247.5208     1         2     3
# 262.375      1         6     7
# 263.0        2         4     6
# 512.3292     0         4     4
# All        618       427  1045
#
# [257 rows x 3 columns]

# %%
#embarked

pd.crosstab(titanic_copy["embarked"], titanic_copy['survived'], margins=True)
# Out:
# survived     Died  Survived   All
# embarked
# Cherbourg      80       132   212
# Queenstown     37        13    50
# Southampton   502       282   784
# All           619       427  1046

# %% [markdown]
# ### Characteristics of passenger most influenced their survival
#
# Survival of person depends from their status: most likely the passenger, not a crew member will survive.
#
# Adult single woman from the first class wass the most frequant surviver.

# %% [markdown]
# ### Visualize your Results
#
# * Using the most interesting (from your POV) results from the above section, create (3) visualizations to illustrate the results.
# * Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?
# * Create a violin plot to show the distribution of age across passenger class.

# %%
sns.countplot(data = titanic_copy, x = "survived", hue = "pclass")
plt.title('survival by passenger class')
# Out:
# Text(0.5, 1.0, 'survival by passenger class')

# %%
sns.countplot(data = titanic_copy, x = "survived", hue = "sex")
plt.title('survival by sex')
# Out:
# Text(0.5, 1.0, 'survival by sex')

# %%
sns.countplot(data= titanic_copy, x='survived', hue="Age Group")
plt.title("survival by age group")
# Out:
# Text(0.5, 1.0, 'survival by age group')

# %%
sns.countplot(data= titanic_copy, x='survived', hue="age")
plt.title("survival by age")
# Out:
# Text(0.5, 1.0, 'survival by age')

# %%
sns.countplot(data= titanic_copy, x='survived', hue="Family Size")
plt.title("survival by family size")
# Out:
# Text(0.5, 1.0, 'survival by family size')

# %%
sns.countplot(data= titanic_copy, x='survived', hue="Family Size")
plt.title("survival by family size")

# %%
sns.countplot(data= titanic_copy, x='survived', hue="fare")
plt.title("survival by fare")
# Out:
# Text(0.5, 1.0, 'survival by fare')

# %%
titanic_copy.corr()
# Out:
#                         age     sibsp     parch      fare  Titanic Passenger  \
# age                1.000000 -0.243699 -0.150917  0.178739                NaN
# sibsp             -0.243699  1.000000  0.374456  0.141184                NaN
# parch             -0.150917  0.374456  1.000000  0.216723                NaN
# fare               0.178739  0.141184  0.216723  1.000000                NaN
# Titanic Passenger       NaN       NaN       NaN       NaN                NaN
# Family Size       -0.240230  0.844260  0.813080  0.213916                NaN
# Travel Alone       0.128755 -0.627380 -0.570062 -0.259822                NaN
#
#                    Family Size  Travel Alone
# age                  -0.240230      0.128755
# sibsp                 0.844260     -0.627380
# parch                 0.813080     -0.570062
# fare                  0.213916     -0.259822
# Titanic Passenger          NaN           NaN
# Family Size           1.000000     -0.723375
# Travel Alone         -0.723375      1.000000

# %% [markdown]
# Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?

# %%
sns.barplot(x=titanic_copy['pclass'], y = titanic_copy['age'])
plt.title('Average of Age by Passenger Class')
plt.minorticks_on()

# %% [markdown]
# ### Interpretation¶
# On average, the 1st passenger class has the oldest passengers: 35 - 39

# %%
sns.barplot(x=titanic_copy['pclass'], y = titanic_copy['fare'])
plt.title('Average of fare by Passenger Class')
plt.minorticks_on()

# %% [markdown]
# Create a barplot to show the variation in average age across passenger class. On average, which passenger class has the oldest passengers?

# %%
sns.violinplot(x = titanic_copy["pclass"], y = titanic_copy["age"])
plt.title('Distribution of Age by Passenger Class')
plt.minorticks_on()

# %% [markdown]
# ### Interpretation
#
# The 1st class has the oldest passengers.

# %%
import statsmodels.formula.api as sm
result = sm.ols('survived ~ age + fare + sibsp + parch + C(sex)', data = titanic).fit()

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               survived   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.322
# Method:                 Least Squares   F-statistic:                     99.97
# Date:                Tue, 16 May 2023   Prob (F-statistic):           3.99e-86
# Time:                        12:51:20   Log-Likelihood:                -535.47
# No. Observations:                1045   AIC:                             1083.
# Df Residuals:                    1039   BIC:                             1113.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.7898      0.037     21.382      0.000       0.717       0.862
# C(sex)[T.male]    -0.5193      0.027    -19.272      0.000      -0.572      -0.466
# age               -0.0028      0.001     -3.022      0.003      -0.005      -0.001
# fare               0.0016      0.000      6.786      0.000       0.001       0.002
# sibsp             -0.0552      0.015     -3.623      0.000      -0.085      -0.025
# parch             -0.0075      0.017     -0.447      0.655      -0.040       0.025
# ==============================================================================
# Omnibus:                       30.609   Durbin-Watson:                   1.803
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.441
# Skew:                           0.420   Prob(JB):                     9.03e-08
# Kurtosis:                       2.804   Cond. No.                         226.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
result.predict({
    'fare': 262, 
    'age': 20, 
    'sibsp': 1, 
    'parch': 0,
    'sex': "female"})
# Out:
# 0    1.106586
# dtype: float64

# %%
result.predict({
    'fare': 262, 
    'age': 20, 
    'sibsp': 1, 
    'parch': 0,
    'sex': "male"})
# Out:
# 0    0.587334
# dtype: float64
